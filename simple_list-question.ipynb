# %% [markdown]
# ### `Problem 1:` Combine two lists index-wise(columns wise)
#
# Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# `Given List:`
# ```
# list1 = ["M", "na", "i", "Kh"]
# list2 = ["y", "me", "s", "an"]
# ```
#
# `Output:`
# ```
# [['M','y'], ['na', me'], ['i', 's'], ['Kh', 'an']]
# ```

# %%
# Write code here
list1 = ["M", "na", "i", "Kh"]
list2 = ["y", "me", "s", "an"]
list3= []

for i in range(len(list1)):
  list3.append([list1[i], list2[i]])

print(list3)
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Kh', 'an']]

# %% [markdown]
# ### `Problem 2:` Add new item to list after a specified item
# Write a program to add item 7000 after 6000 in the following Python List
# ```
# list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# ```
# `Output:`
# ```
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]
# ```

# %%
# Write code here
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)

list1
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ###`Problem 3:` Update no of items available
#
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# i.e -
# ```
# candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# no_of_items = [10,20,34,74,32]
# ```
#
# Write a program to show no. of items of each candy type.
#
# `Output:`
#
# ```
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]
# num1 = 1
# string = "s"
# print(string +str(num1))

list2 = []
for i in range(len(candy_list)):
    combine = candy_list[i]   +"-" + str(no_of_items[i])
    print(combine)
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %% [markdown]
# ###`Problem 4:` Running Sum on list
# Write a program to print a list after performing running sum on it.
#
# i.e:
#
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,3,6,10,15,21]
# ```

# %%
# Write code here
list1 = [1,2,3,4,5,6]
total = 0 
running_sum  = []
for i in list1:
  total = total + i
  running_sum.append(total)

running_sum
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ###`Problem 6:` Find list of common unique items from two list. and show in increasing order
#
# `Input`
#
# ```
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# ```
#
# `Output:`
# ```
# [34, 67, 89]
# ```

# %%
# Write code here

num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]
list2 = []
for i  in range (len(num1)):
  for j in range (len(num1)):
    if num1[i] == num2[j]:
      list2.append(num2[j])


list2.sort()

list2
# Out:
# [34, 67, 89]

# %% [markdown]
# `Problem 8:` Split String of list on K character.
#
# **Example :**
#
# Input:
# ```bash
# ['CampusX is a channel', 'for data-science', 'aspirants.']
# ```
#
# Output:
# ```bash
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']
# ```

# %%
# Write code here
list11= ['CampusX is a channel', 'for data-science', 'aspirants.']
x = ""

# combine =list11[0] + list11[1]

for i in list11:
  x= x + " " + i




print(x.split())
# Out:
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']

# %% [markdown]
# ### `Problem 9:` Convert Character Matrix to single String using string comprehension.
#
# **Example 1:**
#
# Input:
# ```bash
# [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
# ```
#
# Output:
# ```bash
# campux is best channel
# ```

# %%
list1= [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]

# %%
# combine = " "
# for i in list1:
#     for j in i :
#         # combine = combine + " " +j
        
# combine


list2 = [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's']]
combine =" " 
for i in  list2:
    for j in i:
        combine =combine + j
combine
# Out:
# ' campuxis'

# %%
def convertToTitle( columnNumber):
    """
    :type columnNumber: int
    :rtype: str
    """
    result = ""
    while columnNumber > 0:
        columnNumber -= 1
        result = chr(columnNumber % 26 + ord('A')) + result
        columnNumber //= 26
    return result

# %%
# Out:
# ZY

# %%
ord('A')
# Out:
# 65

# %%
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
result = ""
columnNumber= 100
 
while columnNumber > 0:
        columnNumber -= 1
        remainder = columnNumber % 26
        result = letters[remainder] + result  # Get letter from string
        columnNumber //= 26
    
print(result)
# Out:
# CV

# %%
s = ["h","e","l","l","o"]
# Out:
# h
# e
# l
# l
# o
# h

# %%
s = ["h","e","l","l","o"]

for i in range (len(s)-1, -1, -1):
    print(s[i])
# Out:
# o
# l
# l
# e
# h

# %%
class Solution(object):
    def reverseString(self, s):
        y = []
        for i in range (len(s)-1, -1, -1):
            y.append(s[i])
        return y

# %%
s = ["H","a","n","n","a","h"]
solution = Solution()
solution.reverseString(s)
# Out:
# ['h', 'a', 'n', 'n', 'a', 'H']

# %%
import time
for x in "pakistan":
    print(x)    
    time.sleep(1)
# Out:
# p
# a
# k
# i
# s
# t
# a
# n

# %%
nums = [4,1,2,1,2]
#how can i find the number which is not repeated in the list
for i in nums:
    if nums.count(i) == 1:
        print(i)
# Out:
# 4

# %%
def singleNumber(nums):
    for i in nums:
        if nums.count(i) == 1:
            return i

# %%
xyz = [4,1,2,1,2]
print(singleNumber(xyz))
# Out:
# 4

# %%
num1 = "11"
num2 = "123"

def addStrings(num1, num2):
    return str(int(num1) + int(num2))

# %%
Solution = addStrings(num1, num2)
print(Solution)
# Out:
# 134

# %%
x=10
x^2
# Out:
# 8

# %%
x.sqrt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x.sqrt()
#
# AttributeError: 'int' object has no attribute 'sqrt'

# %%
import math
math.sqrt(x)
# Out:
# 3.1622776601683795

# %%
Romannumber = "IVI"
splitted =Romannumber.split()

pakistan = "Pakistan"
splittedpakistan = pakistan.split()
roman_dict = {
    "I" : 1,    
    "V" : 5,
     "X" : 10,
     "L" : 50,
     "C" : 100,
     "D" : 500,
     "M" : 1000
}

splitted
# Out:
# ['IVI']

# %%
def romanToInt(s):
    roman_dict = {
        "I": 1, "V": 5, "X": 10,
        "L": 50, "C": 100, "D": 500,
        "M": 1000
    }
    total = 0
    prev_value = 0
    for ch in reversed(s):
        value = roman_dict[ch]
        if value < prev_value:
            total -= value
        else:
            total += value
        prev_value = value
    return total

# examples
print(romanToInt("III"))    # 3
print(romanToInt("IV"))     # 4
print(romanToInt("IX"))     # 9
print(romanToInt("LVIII"))  # 58
print(romanToInt("MCMXCIV"))# 1994
# Out:
# 3
# 4
# 9
# 58
# 1994

# %%
sum = 0
for  i in Romannumber:
    
    sum = sum + roman_dict[i]

# %%
sum
# Out:
# 2216
